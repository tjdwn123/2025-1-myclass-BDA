# %% [markdown]
# <a href="https://colab.research.google.com/github/tjdwn123/2025-1-myclass-BDA/blob/main/inclass/02W_A_0317_pandas_basic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# > 시리즈 활용

# %%
import numpy as np
import pandas as pd

s=['희빈','수영','한영','지호','지민']
p= pd.Series([99,84,92,65,78],index=s)
p
# Out:
# 희빈    99
# 수영    84
# 한영    92
# 지호    65
# 지민    78
# dtype: int64

# %%
p.name='수학성적'
p.index.name='이름'
p
# Out:
# 이름
# 희빈    99
# 수영    84
# 한영    92
# 지호    65
# 지민    78
# Name: 수학성적, dtype: int64

# %%
p.sort_index()
# Out:
# 이름
# 수영    84
# 지민    78
# 지호    65
# 한영    92
# 희빈    99
# Name: 수학성적, dtype: int64

# %%
p.sort_index(ascending=False)
# Out:
# 이름
# 희빈    99
# 한영    92
# 지호    65
# 지민    78
# 수영    84
# Name: 수학성적, dtype: int64

# %%
p.sort_values()
# Out:
# 이름
# 지호    65
# 지민    78
# 수영    84
# 한영    92
# 희빈    99
# Name: 수학성적, dtype: int64

# %%
p.sort_values(ascending=False)
# Out:
# 이름
# 희빈    99
# 한영    92
# 수영    84
# 지민    78
# 지호    65
# Name: 수학성적, dtype: int64

# %%
print(p.max())
print(p.min())
print(p.mean())
print(p.count)
print()
print()
# Out:
# 99
# 65
# 83.6
# <bound method Series.count of 이름
# 희빈    99
# 수영    84
# 한영    92
# 지호    65
# 지민    78
# Name: 수학성적, dtype: int64>

# %%
p.describe
# Out:
# <bound method NDFrame.describe of 이름
# 희빈    99
# 수영    84
# 한영    92
# 지호    65
# 지민    78
# Name: 수학성적, dtype: int64>

# %%
s= pd.Series([3,1,1,2,None,np.nan,4,6,6,np.nan])
s
# Out:
# 0    3.0
# 1    1.0
# 2    1.0
# 3    2.0
# 4    NaN
# 5    NaN
# 6    4.0
# 7    6.0
# 8    6.0
# 9    NaN
# dtype: float64

# %%
s.values
# Out:
# array([ 3.,  1.,  1.,  2., nan, nan,  4.,  6.,  6., nan])

# %%
s.value_counts(bins=4)
# Out:
# (0.994, 2.25]    3
# (4.75, 6.0]      2
# (2.25, 3.5]      1
# (3.5, 4.75]      1
# Name: count, dtype: int64

# %%
s.value_counts(bins=4,sort=False)
# Out:
# (0.994, 2.25]    3
# (2.25, 3.5]      1
# (3.5, 4.75]      1
# (4.75, 6.0]      2
# Name: count, dtype: int64

# %%
s.value_counts(bins=[0.5,3.5,6.5],sort=False)
# Out:
# (0.499, 3.5]    4
# (3.5, 6.5]      3
# Name: count, dtype: int64

# %% [markdown]
# 데이터프레임 기초

# %%
import pandas as pd

df=pd.DataFrame([10,20,30,40,50])
df
# Out:
#     0
# 0  10
# 1  20
# 2  30
# 3  40
# 4  50

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df=pd.DataFrame([[1,2,3],[10,20,30],[100,200,300]],index=list('abc'))
df
# Out:
#      0    1    2
# a    1    2    3
# b   10   20   30
# c  100  200  300

# %%
list('abc')
# Out:
# ['a', 'b', 'c']

# %%
df=pd.DataFrame([[1,2,3],[10,20,30],[100,200,300]],index=list('abc'),columns=['A','B','C'])

# %%
df.index
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C'], dtype='object')

# %%
df1=pd.DataFrame(data=np.arange(12).reshape(4,3))
df1
# Out:
#    0   1   2
# 0  0   1   2
# 1  3   4   5
# 2  6   7   8
# 3  9  10  11

# %%
np.random.seed(100)
df1=pd.DataFrame(np.random.randint(1,46,(5,6)))
df1
# Out:
#     0   1   2   3   4   5
# 0   9  25   4  40  24  16
# 1  11  31  35   3  35  15
# 2  35  25  16  37  44  17
# 3  10  30  23   3  28  45
# 4   5  32   2  14  20  37

# %%
df1=pd.DataFrame(np.random.random((5,3)))
df1
# Out:
#           0         1         2
# 0  0.175410  0.372832  0.005689
# 1  0.252426  0.795663  0.015255
# 2  0.598843  0.603805  0.105148
# 3  0.381943  0.036476  0.890412
# 4  0.980921  0.059942  0.890546

# %%
df=pd.DataFrame({'numbers':[1,2,3],'colors':['red','white','blue']})
df
# Out:
#    numbers colors
# 0        1    red
# 1        2  white
# 2        3   blue

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.columns
# Out:
# Index(['numbers', 'colors'], dtype='object')

# %%
df=pd.DataFrame({'국어':[82,76,67],'수학':[99,87,78]},index=['김국진','진영희','이결순'])
df
# Out:
#      국어  수학
# 김국진  82  99
# 진영희  76  87
# 이결순  67  78

# %%
df.columns
# Out:
# Index(['국어', '수학'], dtype='object')

# %%
df.index
# Out:
# Index(['김국진', '진영희', '이결순'], dtype='object')

# %%
courses=pd.Series(["Spark","PySpark","Hadoop"],name='courses')
courses # Corrected the typo from 'courese' to 'courses'
# Out:
# 0      Spark
# 1    PySpark
# 2     Hadoop
# Name: courses, dtype: object

# %%
fees=pd.Series([25000,30000,20000],name='feea')
fees
# Out:
# 0    25000
# 1    30000
# 2    20000
# Name: feea, dtype: int64

# %%
pd.DataFrame({courses.name:courses,fees.name:fees}) # Call pd.DataFrame directly
# Out:
#    courses   feea
# 0    Spark  25000
# 1  PySpark  30000
# 2   Hadoop  20000

# %%
df=pd.concat([courses,fees],axis=0)
df
# Out:
# 0      Spark
# 1    PySpark
# 2     Hadoop
# 0      25000
# 1      30000
# 2      20000
# dtype: object

# %%
df=pd.DataFrame([courses,fees])
df
# Out:
#              0        1       2
# courses  Spark  PySpark  Hadoop
# feea     25000    30000   20000

# %%
df.T
# Out:
#    courses   feea
# 0    Spark  25000
# 1  PySpark  30000
# 2   Hadoop  20000

# %%
df=pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df[courses.name]=courses
df
# Out:
#    courses
# 0    Spark
# 1  PySpark
# 2   Hadoop

# %%
df[fees.name]=fees
df
# Out:
#    courses   feea
# 0    Spark  25000
# 1  PySpark  30000
# 2   Hadoop  20000

# %%
df=pd.DataFrame([{'국어':70,'수학':89,'영어':90},
                 {'국어':70,'영어':99},
                 {'국어':70,'수학':78}])
df
# Out:
#    국어    수학    영어
# 0  70  89.0  90.0
# 1  70   NaN  99.0
# 2  70  78.0   NaN

# %%
s1=pd.Series([90,80,60,66])
s2=pd.Series([45,73,83,99])
s3=pd.Series([92,75,82,75])
s1
# Out:
# 0    90
# 1    80
# 2    60
# 3    66
# dtype: int64

# %%
df=pd.DataFrame({'국어':s1,'영어':s2,'수학':s3})
df
# Out:
#    국어  영어  수학
# 0  90  45  92
# 1  80  73  75
# 2  60  83  82
# 3  66  99  75

# %%
df=pd.DataFrame({'A':pd.Series([10,20,30], index=[0,1,2]),'B':pd.Series([3,2,1],index=[1,2,3])})
df
# Out:
#       A    B
# 0  10.0  NaN
# 1  20.0  3.0
# 2  30.0  2.0
# 3   NaN  1.0

# %%
d={'col1':[1,2],'col2':[3,4]}
df=pd.DataFrame(d)
df
# Out:
#    col1  col2
# 0     1     3
# 1     2     4

# %%
df.dtypes
# Out:
# col1    int64
# col2    int64
# dtype: object

# %%
df=pd.DataFrame(d,dtype=np.int8)
df.dtypes
# Out:
# col1    int8
# col2    int8
# dtype: object

# %% [markdown]
# 날짜데이터

# %%
dates=pd.date_range('20250101',periods=6)
dates
# Out:
# DatetimeIndex(['2025-01-01', '2025-01-02', '2025-01-03', '2025-01-04',
#                '2025-01-05', '2025-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
dates[0]
# Out:
# Timestamp('2025-01-01 00:00:00')

# %%
type(dates[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
dates = pd.date_range("20250101", periods=6, freq='4h') # Changed 'data_range' to 'date_range'
dates
# Out:
# DatetimeIndex(['2025-01-01 00:00:00', '2025-01-01 04:00:00',
#                '2025-01-01 08:00:00', '2025-01-01 12:00:00',
#                '2025-01-01 16:00:00', '2025-01-01 20:00:00'],
#               dtype='datetime64[ns]', freq='4h')

# %%
dates = pd.date_range("20250101", periods=6, freq='W-SUN')
dates
# Out:
# DatetimeIndex(['2025-01-05', '2025-01-12', '2025-01-19', '2025-01-26',
#                '2025-02-02', '2025-02-09'],
#               dtype='datetime64[ns]', freq='W-SUN')

# %%
dates = pd.date_range("20250101", periods=6, freq='ME')
dates
# Out:
# DatetimeIndex(['2025-01-31', '2025-02-28', '2025-03-31', '2025-04-30',
#                '2025-05-31', '2025-06-30'],
#               dtype='datetime64[ns]', freq='ME')

# %%
dates = pd.date_range("20250101", periods=6, freq='MS')
dates
# Out:
# DatetimeIndex(['2025-01-01', '2025-02-01', '2025-03-01', '2025-04-01',
#                '2025-05-01', '2025-06-01'],
#               dtype='datetime64[ns]', freq='MS')

# %%
dates = pd.date_range("20250302", periods=6,)
dates
# Out:
# DatetimeIndex(['2025-03-02', '2025-03-03', '2025-03-04', '2025-03-05',
#                '2025-03-06', '2025-03-07'],
#               dtype='datetime64[ns]', freq='D')

# %%
df=pd.DataFrame(np.random.randn(6,4),index=dates,columns=list('ABCD'))
df
# Out:
#                    A         B         C         D
# 2025-03-02  1.567179  0.497025  1.155872  1.838612
# 2025-03-03  1.535727  0.254998 -0.844157 -0.982943
# 2025-03-04 -0.306098  0.838501 -1.690848  1.151174
# 2025-03-05 -1.029337 -0.510992 -2.360271  0.103595
# 2025-03-06  1.738818  1.241876  0.132413  0.577794
# 2025-03-07 -1.575906 -1.292794 -0.659920 -0.874005

# %%
df2=pd.DataFrame({
    "A":1.0,
    "B":pd.Timestamp("20130102"),
    "C":pd.Series(1,index=list(range(4)),dtype="float32"),
    "D":np.array([3]*4,dtype="int32"),
})

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       4 non-null      float64
#  1   B       4 non-null      datetime64[s]
#  2   C       4 non-null      float32
#  3   D       4 non-null      int32
# dtypes: datetime64[s](1), float32(1), float64(1), int32(1)
# memory usage: 128.0 bytes
