# %% [markdown]
# <a href="https://colab.research.google.com/github/tjdwn123/2025-1-myclass-BDA/blob/main/inclass/05w_A_mon_0407_easy_ch05_06_dataframe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 05주 수업

# %% [markdown]
# ##p116 05-03 파생변수 생건 p116

# %%
import pandas as pd
import numpy as np

df=pd.DataFrame({'var1':[4,3,8],'var2':[2,6,1]})
df
# Out:
#    var1  var2
# 0     4     2
# 1     3     6
# 2     8     1

# %%
df1=df.copy()
df1
# Out:
#    var1  var2
# 0     4     2
# 1     3     6
# 2     8     1

# %%
df1['var_sum']=df1.var1+df1.var2
df1
# Out:
#    var1  var2  var_sum
# 0     4     2        6
# 1     3     6        9
# 2     8     1        9

# %%
df1.var_sum2=df1.var1+df1.var2
df1
# Out:
# <ipython-input-5-52ed6f7e3855>:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df1.var_sum2=df1.var1+df1.var2
#    var1  var2  var_sum
# 0     4     2        6
# 1     3     6        9
# 2     8     1        9

# %%
df1['var_mean']=(df1.var1+df1.var2)/2
df1
# Out:
#    var1  var2  var_sum  var_mean
# 0     4     2        6       3.0
# 1     3     6        9       4.5
# 2     8     1        9       4.5

# %%
df
# Out:
#    var1  var2
# 0     4     2
# 1     3     6
# 2     8     1

# %%
df1
# Out:
#    var1  var2  var_sum  var_mean
# 0     4     2        6       3.0
# 1     3     6        9       4.5
# 2     8     1        9       4.5

# %%
df2=df.copy()
df2
# Out:
#    var1  var2
# 0     4     2
# 1     3     6
# 2     8     1

# %%
df2.sum()
# Out:
# var1    15
# var2     9
# dtype: int64

# %%
df2.sum(axis=0)
# Out:
# var1    15
# var2     9
# dtype: int64

# %%
df2.sum(axis=1)
# Out:
# 0    6
# 1    9
# 2    9
# dtype: int64

# %%
df2['my_sum']=df2.sum(axis=1)
df2
# Out:
#    var1  var2  my_sum
# 0     4     2       6
# 1     3     6       9
# 2     8     1       9

# %%
df2[["var1","var2"]]
# Out:
#    var1  var2
# 0     4     2
# 1     3     6
# 2     8     1

# %%
df2['my_sum'] = df2.sum(axis='columns') # Changed 'colums' to 'columns'
df2
# Out:
#    var1  var2  my_sum
# 0     4     2      12
# 1     3     6      18
# 2     8     1      18

# %%
df2["my_mean"] = df2[["var1","var2"]].mean(axis='columns')
df2
# Out:
#    var1  var2  my_sum  my_mean
# 0     4     2      12      3.0
# 1     3     6      18      4.5
# 2     8     1      18      4.5

# %% [markdown]
# ##mpg 데이터

# %%
# !git clone https://github.com/ai7dnn/data
# Out:
# Cloning into 'data'...
# remote: Enumerating objects: 24, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 24 (delta 4), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (24/24), 2.14 MiB | 5.43 MiB/s, done.
# Resolving deltas: 100% (4/4), done.

# %%
mpg=pd.read_csv('data/mpg.csv')
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    object
#  10  category      234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 20.2+ KB

# %%
mpg.sample()
# Out:
#    manufacturer        model  displ  year  cyl     trans drv  cty  hwy fl  \
# 37        dodge  caravan 2wd    2.4  1999    4  auto(l3)   f   18   24  r
#
#    category
# 37  minivan

# %%
mpg['total']=(mpg.cty+mpg.hwy)/2
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl category  \
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact
#
#    total  mpg_mean
# 0   23.5      23.5
# 1   25.0      25.0
# 2   25.5      25.5
# 3   25.5      25.5
# 4   21.0      21.0

# %%
mpg['mpg_mean']=mpg[['cty','hwy']].mean(axis=1)
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl category  \
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact
#
#    total  mpg_mean
# 0   23.5      23.5
# 1   25.0      25.0
# 2   25.5      25.5
# 3   25.5      25.5
# 4   21.0      21.0

# %%
mpg['mpg_mean']=mpg[['cty','hwy']].mean(axis='columns')
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl category  \
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact
#
#    total  mpg_mean
# 0   23.5      23.5
# 1   25.0      25.0
# 2   25.5      25.5
# 3   25.5      25.5
# 4   21.0      21.0

# %%
sum(mpg['total']) / len(mpg)
# Out:
# 20.14957264957265

# %%
mpg['total'].mean()
# Out:
# np.float64(20.14957264957265)

# %%
mpg.shape
# Out:
# (234, 13)

# %%
len(mpg)
# Out:
# 234

# %%
sum(mpg['total'])/mpg.shape[0]
# Out:
# 20.14957264957265

# %%
mpg['total'].describe()
# Out:
# count    234.000000
# mean      20.149573
# std        5.050290
# min       10.500000
# 25%       15.500000
# 50%       20.500000
# 75%       23.500000
# max       39.500000
# Name: total, dtype: float64

# %%
mpg['total'].describe()['mean']
# Out:
# np.float64(20.14957264957265)

# %%
mpg.total.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
mpg['total'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
# !pip install koreanize-matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 48.5 MB/s eta 0:00:00
# ...

# %%
import koreanize_matplotlib

# %%
# %config InlineBackend.figure_format='retina'

# %%
mpg.total.plot(kind='hist',title='히스토그램')
# Out:
# <Axes: title={'center': '히스토그램'}, ylabel='Frequency'>

# %%
import seaborn as sns

sns.histplot(mpg, x='total')
# Out:
# <Axes: xlabel='total', ylabel='Count'>

# %% [markdown]
# ##np.where()

# %%
np.where(mpg.total>20,'pass','fail')
# Out:
# array(['pass', 'pass', 'pass', 'pass', 'pass', 'pass', 'pass', 'pass',
#        'pass', 'pass', 'pass', 'fail', 'pass', 'pass', 'fail', 'fail',
#        'pass', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'pass',
#        'fail', 'pass', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail',
#        'pass', 'pass', 'pass', 'pass', 'pass', 'pass', 'pass', 'fail',
#        'fail', 'pass', 'pass', 'fail', 'fail', 'fail', 'fail', 'fail',
#        'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail',
#        'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail',
#        'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail',
#        'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail',
#        'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail',
#        'fail', 'fail', 'pass', 'pass', 'pass', 'fail', 'fail', 'fail',
#        'fail', 'fail', 'fail', 'pass', 'pass', 'pass', 'pass', 'pass',
# ...

# %%
mpg['test']=np.where(mpg.total>20,'pass','fail')
mpg.sample(5)
# Out:
#     manufacturer                model  displ  year  cyl       trans drv  cty  \
# 183       toyota                camry    3.0  1999    6    auto(l4)   f   18
# 160       subaru         forester awd    2.5  1999    4    auto(l4)   4   18
# 66         dodge  ram 1500 pickup 4wd    4.7  2008    8    auto(l5)   4   13
# 78          ford         explorer 4wd    4.0  1999    6  manual(m5)   4   15
# 113      hyundai               sonata    2.5  1999    6  manual(m5)   f   18
#
#      hwy fl category  total  mpg_mean  test
# 183   26  r  midsize   22.0      22.0  pass
# 160   24  r      suv   21.0      21.0  pass
# 66    17  r   pickup   15.0      15.0  fail
# 78    19  r      suv   17.0      17.0  fail
# 113   26  r  midsize   22.0      22.0  pass

# %%
mpg['test'].value_counts()
# Out:
# test
# pass    123
# fail    111
# Name: count, dtype: int64

# %%
mpg['test'].unique()
# Out:
# array(['pass', 'fail'], dtype=object)

# %%
count_test = mpg['test'].value_counts()  # 연비 합격 빈도표를 변수에 할당
count_test
# Out:
# test
# pass    123
# fail    111
# Name: count, dtype: int64

# %%
count_test.plot.bar();

# %%
count_test.plot.bar(rot = 0);

# %%
sns.countplot(mpg, x="test",hue='test');

# %%
sns.countplot(mpg, x="test",hue='test',stat='percent');

# %%
sns.countplot(mpg, x='test',hue='cyl',stat='percent');

# %%
sns.countplot(mpg, x='test',hue='category',stat='percent');

# %%
mpg['grade'] = np.where(mpg['total'] >= 30, 'A',
               np.where(mpg['total'] >= 20, 'B', 'C'))

# %%
mpg.sample(5)
# Out:
#     manufacturer              model  displ  year  cyl       trans drv  cty  \
# 112      hyundai             sonata    2.5  1999    6    auto(l4)   f   18
# 91          ford            mustang    3.8  1999    6    auto(l4)   r   18
# 59         dodge        durango 4wd    4.7  2008    8    auto(l5)   4    9
# 26     chevrolet           corvette    6.2  2008    8    auto(s6)   r   15
# 55         dodge  dakota pickup 4wd    5.2  1999    8  manual(m5)   4   11
#
#      hwy fl    category  total  mpg_mean  test geade grade
# 112   26  r     midsize   22.0      22.0  pass     B     B
# 91    25  r  subcompact   21.5      21.5  pass     B     B
# 59    12  e         suv   10.5      10.5  fail     c     C
# 26    25  p     2seater   20.0      20.0  fail     B     B
# 55    17  r      pickup   14.0      14.0  fail     c     C

# %%
count_grade = mpg['grade'].value_counts()  # 등급 빈도표 만들기
count_grade
# Out:
# grade
# B    118
# C    106
# A     10
# Name: count, dtype: int64

# %%
mpg['geade']=np.where(mpg.total>=30,'A',np.where(mpg.total>=20,'B',"c"))
mpg.sample(5)
# Out:
#     manufacturer           model  displ  year  cyl       trans drv  cty  hwy  \
# 180       toyota           camry    2.2  1999    4    auto(l4)   f   21   27
# 176       toyota     4runner 4wd    3.4  1999    6  manual(m5)   4   15   17
# 153       nissan  pathfinder 4wd    5.6  2008    8    auto(s5)   4   12   18
# 24     chevrolet        corvette    5.7  1999    8    auto(l4)   r   15   23
# 80          ford    explorer 4wd    4.0  2008    6    auto(l5)   4   13   19
#
#     fl category  total  mpg_mean  test geade
# 180  r  midsize   24.0      24.0  pass     B
# 176  r      suv   16.0      16.0  fail     c
# 153  p      suv   15.0      15.0  fail     c
# 24   p  2seater   19.0      19.0  fail     c
# 80   r      suv   16.0      16.0  fail     c

# %%
sns.countplot(mpg, x='geade',hue='grade');

# %%
sns.countplot(mpg, x='test',hue='grade',stat='percent');

# %%
mpg.grade.value_counts().sort_index().index
# Out:
# Index(['A', 'B', 'C'], dtype='object', name='grade')

# %%
sns.countplot(x='grade', hue='grade', data=mpg, order=mpg.grade.value_counts().sort_index().index)
# Out:
# <Axes: xlabel='grade', ylabel='count'>

# %%
np.sort(mpg.grade.unique())
# Out:
# array(['A', 'B', 'C'], dtype=object)

# %%
s=mpg.grade
s=s.value_counts()
s=s.sort_index()
type(s)
# Out:
# pandas.core.series.Series

# %%
s=mpg.grade.value_counts()
s=s.sort_index()
type(s)
# Out:
# pandas.core.series.Series

# %%
mpg['grade']=np.where(mpg.total>=30,"A",
             np.where(mpg.total>=25,"B",
             np.where(mpg.total>=20,"C","D")))
mpg.sample(5)
# Out:
#     manufacturer           model  displ  year  cyl       trans drv  cty  hwy  \
# 225   volkswagen      new beetle    2.5  2008    5  manual(m5)   f   20   28
# 40         dodge     caravan 2wd    3.3  1999    6    auto(l4)   f   16   22
# 150       nissan  pathfinder 4wd    3.3  1999    6    auto(l4)   4   14   17
# 217   volkswagen           jetta    2.5  2008    5    auto(s6)   f   21   29
# 113      hyundai          sonata    2.5  1999    6  manual(m5)   f   18   26
#
#     fl    category  total  mpg_mean  test geade grade
# 225  r  subcompact   24.0      24.0  pass     B     C
# 40   r     minivan   19.0      19.0  fail     c     D
# 150  r         suv   15.5      15.5  fail     c     D
# 217  r     compact   25.0      25.0  pass     B     B
# 113  r     midsize   22.0      22.0  pass     B     C

# %%
mpg['size']=np.where((mpg.category=='compact')|(mpg.category=='subcompact')|(mpg.category=='2seater'),'small','large')

# %%
mpg['size'].value_counts()
# Out:
# size
# large    147
# small     87
# Name: count, dtype: int64

# %%
mpg['size']=np.where(mpg.category.isin(['compact','subcompact','2seater']),'small','large')
mpg['size'].value_counts()
# Out:
# size
# large    147
# small     87
# Name: count, dtype: int64

# %% [markdown]
# 정리하기

# %%
# 1. 패키지 로드
import pandas as pd
import numpy as np

# 2. 데이터 불러오기
mpg = pd.read_csv('data/mpg.csv')

# 3. 데이터 파악하기
mpg.shape       # 행, 열 수
mpg.head()      # 데이터 앞부분
mpg.tail()      # 데이터 뒷부분
mpg.info()      # 속성
mpg.describe()  # 요약 통계량

# 4. 변수명 바꾸기
mpg = mpg.rename(columns = {'manufacturer' : 'company'})

# 5. 파생변수 만들기
mpg['total'] = (mpg['cty'] + mpg['hwy'])/2                  # 변수 조합
mpg['test'] = np.where(mpg['total'] >= 20, 'pass', 'fail')  # 조건문 활용

# 6. 빈도 확인하기
count_test = mpg['test'].value_counts()  # 빈도표 만들기
count_test.plot.bar(rot = 0)             # 빈도 막대 그래프 만들기
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    object
#  10  category      234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 20.2+ KB
# <Axes: xlabel='test'>
